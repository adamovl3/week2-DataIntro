# %% [markdown]
# # Research Question, Dataset, and Ethics Check
#
# Use this notebook to document three things for your proposed research project:
#
# 1. Your research question
# 2. The dataset you plan to use
# 3. The ethical aspects you have considered
#
# > Do not load or analyse the data in this notebook. Choose a dataset, provide a reliable reference link, explain why you chose it, and answer the ethics questions using the dataset documentation and any relevant research literature. If a question is not applicable, write N/A and explain why.
#
# ## 1. Research Question
#
# - **Main research question:** ['Can sleep quality and duration predict stress' and 'Does a higher stress level increase caffeine intake']
# - **Why is this question interesting or important?** [Both of these potentialy research questions are particularly relevant to college students and as a group we find these topics interesting]
# - **Who might use or care about the answer?** [Students, universities, student unions, cafes, parents (family)]
# - **Possible sub-questions:** ['does sleep duration increase stress levels', 'does low sleep duration increase caffeine intake']
#
# ## 2. Dataset Reference
#
# - **Dataset name:** [Screen Time vs Mental Health]
# - **Source link:** [https://www.kaggle.com/datasets/kylefengkfeng209/screen-time-vs-mental-health-ml-ready/data]
# - **Date accessed:** [2026-09-14]
# - **Who published or collected it?** [Hökby et al. (2025, PLOS Global Public Health)]
# - **Why did you choose this dataset?** [We found it early and compared it to other datasets we could find. We thought it was a clean dataset, its structured, tabular, interesting, revelent and related to our topic]
# - **Evidence or notes:** [Add links, citations, or brief notes that support your choice.]

# %% [markdown]
# ## Research Questions and Answers
#
# For every answer, distinguish between **known evidence**, **reasonable interpretation**, and **unknown information to investigate**.
#
# ### 1. Where did the data come from?
#
# **Answer:** [Known evidence- this dataset is derived by Mind Lab from a study by Hökby et al. (2025, PLOS Global Public Health)]
#
# ### 2. Why was it originally collected?
#
# **Answer:** [Reasonable interpretation- was made to find associations and correlations within the data from Hökby et al. 2025]
#
# ### 3. Who is represented?
#
# **Answer:** [Known evidence- 4,810 Swedish adolescents (ages 12–16) from a prospective, school-based study in Stockholm.]
#
# ### 4. Who might be missing?
#
# **Answer:** [Reasonable interpretation- those excluded could be adolescents who may not have access to a phone]
#
# ### 5. What personal or sensitive information does it contain, explicitly or implicitly?
#
# **Answer:** [Reasonable interpretation- depression is a mental illness, therefore this is collection of medical data, screen time and sleep. Sleep schedules are also sensitive information]
#
# ### 6. What could your analysis reveal that was not obvious in the original data?
#
# **Answer:** [Since this study mainly analysed screen time and depression, our analysis could reveal new correlations or predictions that werent immediately obvious between sleep and depression]
#
# ### 7. Who could benefit from your findings?
#
# **Answer:** [Students and adolescents would definitely benefit, schools and parents could also indirectly benefit from this study through learning the relationship between sleep and depression]
#
# ### 8. Who could be harmed or misrepresented?
#
# **Answer:** [Misrepresentation could occur if the conclusion from our analysis would be that sleep is the only factor that casues depression]
